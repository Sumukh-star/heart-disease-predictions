# %%
import pandas as pd

# %%
df=pd.read_csv("heart.csv")

# %%
df.head(5)
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
df['ChestPainType'].unique()
# Out:
# array(['ATA', 'NAP', 'ASY', 'TA'], dtype=object)

# %%
import copy
df3=df1=copy.deepcopy(df)

# %%
df3.head(10)
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
# 5   39   M           NAP        120          339          0     Normal    170
# 6   45   F           ATA        130          237          0     Normal    170
# 7   54   M           ATA        110          208          0     Normal    142
# 8   37   M           ASY        140          207          0     Normal    130
# 9   48   F           ATA        120          284          0     Normal    120
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# ...

# %%
df["FastingBS"].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df["RestingECG"].unique()
# Out:
# array(['Normal', 'ST', 'LVH'], dtype=object)

# %%
df["ExerciseAngina"].unique()
# Out:
# array(['N', 'Y'], dtype=object)

# %%
df["ST_Slope"].unique()
# Out:
# array(['Up', 'Flat', 'Down'], dtype=object)

# %%
df["Age"].unique()
# Out:
# array([40, 49, 37, 48, 54, 39, 45, 58, 42, 38, 43, 60, 36, 44, 53, 52, 51,
#        56, 41, 32, 65, 35, 59, 50, 47, 31, 46, 57, 55, 63, 66, 34, 33, 61,
#        29, 62, 28, 30, 74, 68, 72, 64, 69, 67, 73, 70, 77, 75, 76, 71],
#       dtype=int64)

# %%
SexEncode={'M':0,'F':1}

# %%
df['Sex']=df['Sex'].apply(lambda x:AgeEncode[x])

# %%
df.head()
# Out:
#    Age  Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0   40    0           ATA       0.70          289          0     Normal
# 1   49    1           NAP       0.80          180          0     Normal
# 2   37    0           ATA       0.65          283          0         ST
# 3   48    1           ASY       0.69          214          0     Normal
# 4   54    0           NAP       0.75          195          0     Normal
#
#    MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0    172              N      0.0       Up             0
# 1    156              N      1.0     Flat             1
# 2     98              N      0.0       Up             0
# 3    108              Y      1.5     Flat             1
# 4    122              N      0.0       Up             0

# %%
PainTypeEncode={'ATA':1,'NAP':2,'ASY':3,'TA':4}

# %%
df['ChestPainType']=df['ChestPainType'].apply(lambda x:PainTypeEncode[x])

# %%
df.head()
df['ST_Slope'].unique()
# Out:
# array(['Up', 'Flat', 'Down'], dtype=object)

# %%
df["FastingBS"].unique()
FastingBsEncode={'Up':1,'Flat':2,'Down':3}

# %%
df['ST_Slope']=df['ST_Slope'].apply(lambda x:FastingBsEncode[x])

# %%
df.head(5)
# Out:
#    Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0   40    0              1       0.70          289          0     Normal
# 1   49    1              2       0.80          180          0     Normal
# 2   37    0              1       0.65          283          0         ST
# 3   48    1              3       0.69          214          0     Normal
# 4   54    0              2       0.75          195          0     Normal
#
#    MaxHR ExerciseAngina  Oldpeak  ST_Slope  HeartDisease
# 0    172              N      0.0         1             0
# 1    156              N      1.0         2             1
# 2     98              N      0.0         1             0
# 3    108              Y      1.5         2             1
# 4    122              N      0.0         1             0

# %%
#df['Cholesterol'].max()--603
#df['Cholesterol'].min()--0
#df['Cholesterol'].sum()/len(df['Cholesterol'])--198.79

# %%
df['MaxHR'].max()--805
df['MaxHR'].min()--60
df['MaxHR'].sum()/len(df['MaxHR'])--335.599
# Out:
# 472.40836819172114

# %%
df['RestingBP']=df3['RestingBP']

# %%
df['RestingBP'].unique()
# Out:
# array([140, 160, 130, 138, 150, 120, 110, 136, 115, 100, 124, 113, 125,
#        145, 112, 132, 118, 170, 142, 190, 135, 180, 108, 155, 128, 106,
#         92, 200, 122,  98, 105, 133,  95,  80, 137, 185, 165, 126, 152,
#        116,   0, 144, 154, 134, 104, 139, 131, 141, 178, 146, 158, 123,
#        102,  96, 143, 172, 156, 114, 127, 101, 174,  94, 148, 117, 192,
#        129, 164], dtype=int64)

# %%
df['RestingBP']=df3['RestingBP']/200

# %%
df['RestingBP']
# Out:
# 0      0.70
# 1      0.80
# 2      0.65
# 3      0.69
# 4      0.75
#        ...
# 913    0.55
# 914    0.72
# 915    0.65
# 916    0.65
# 917    0.69
# Name: RestingBP, Length: 918, dtype: float64

# %%
df.head()
# Out:
#    Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0   40    0              1       0.70          289          0     Normal
# 1   49    1              2       0.80          180          0     Normal
# 2   37    0              1       0.65          283          0         ST
# 3   48    1              3       0.69          214          0     Normal
# 4   54    0              2       0.75          195          0     Normal
#
#    MaxHR ExerciseAngina  Oldpeak  ST_Slope  HeartDisease
# 0    172              N      0.0         1             0
# 1    156              N      1.0         2             1
# 2     98              N      0.0         1             0
# 3    108              Y      1.5         2             1
# 4    122              N      0.0         1             0

# %%
df['RestingECG'].unique()
# Out:
# array(['Normal', 'ST', 'LVH'], dtype=object)

# %%
d={'Normal':1,'ST':2,'LVH':3}

# %%
df['RestingECG']=df['RestingECG'].apply(lambda x:d[x])

# %%
df.head()
# Out:
#    Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0   40    0              1       0.70          289          0           1
# 1   49    1              2       0.80          180          0           1
# 2   37    0              1       0.65          283          0           2
# 3   48    1              3       0.69          214          0           1
# 4   54    0              2       0.75          195          0           1
#
#    MaxHR ExerciseAngina  Oldpeak  ST_Slope  HeartDisease
# 0    172              N      0.0         1             0
# 1    156              N      1.0         2             1
# 2     98              N      0.0         1             0
# 3    108              Y      1.5         2             1
# 4    122              N      0.0         1             0

# %%
#df['Cholesterol'].max()--603
#df['Cholesterol'].min()--0
#df['Cholesterol'].sum()/len(df['Cholesterol'])--198.79

# %%
f={'N':1,'Y':2}

# %%
df['ExerciseAngina']=df['ExerciseAngina'].apply(lambda x:f[x])

# %%
df.head()
# Out:
#    Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0   40    0              1       0.70          289          0           1
# 1   49    1              2       0.80          180          0           1
# 2   37    0              1       0.65          283          0           2
# 3   48    1              3       0.69          214          0           1
# 4   54    0              2       0.75          195          0           1
#
#    MaxHR  ExerciseAngina  Oldpeak  ST_Slope  HeartDisease
# 0    172               1      0.0         1             0
# 1    156               1      1.0         2             1
# 2     98               1      0.0         1             0
# 3    108               2      1.5         2             1
# 4    122               1      0.0         1             0

# %%
df['MaxHR'].max()
df['MaxHR'].min()--60
df['MaxHR'].sum()/len(df['Cholesterol'])--335.599
# Out:
# 472.40836819172114

# %%
df.columns
# Out:
# Index(['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS',
#        'RestingECG', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'ST_Slope',
#        'HeartDisease'],
#       dtype='object')

# %%
df['Age']=df['Age']//10

# %%
df.head()
# Out:
#    Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0    4    0              1       0.70          289          0           1
# 1    4    1              2       0.80          180          0           1
# 2    3    0              1       0.65          283          0           2
# 3    4    1              3       0.69          214          0           1
# 4    5    0              2       0.75          195          0           1
#
#    MaxHR  ExerciseAngina  Oldpeak  ST_Slope  HeartDisease
# 0    172               1      0.0         1             0
# 1    156               1      1.0         2             1
# 2     98               1      0.0         1             0
# 3    108               2      1.5         2             1
# 4    122               1      0.0         1             0

# %%
df['Cholesterol'].max()
#df['Cholesterol'].min()--0
#df['Cholesterol'].sum()/len(df['Cholesterol'])--198.79
#df['Cholesterol'].unique()
# Out:
# 606.0332058433517

# %%
df['Cholesterol']=df['Cholesterol']/(df['Cholesterol'].sum()/len(df['Cholesterol']))

# %%
df.head()
# Out:
#    Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0    4    0              1       0.70     1.453726          0           1
# 1    4    1              2       0.80     0.905435          0           1
# 2    3    0              1       0.65     1.423544          0           2
# 3    4    1              3       0.69     1.076461          0           1
# 4    5    0              2       0.75     0.980887          0           1
#
#    MaxHR  ExerciseAngina  Oldpeak  ST_Slope  HeartDisease
# 0    172               1      0.0         1             0
# 1    156               1      1.0         2             1
# 2     98               1      0.0         1             0
# 3    108               2      1.5         2             1
# 4    122               1      0.0         1             0

# %%
df['Cholesterol'].min()
# Out:
# 0.0

# %%
df['MaxHR']=df['MaxHR']/(df['MaxHR'].sum()/len(df['MaxHR']))

# %%
df.head()
# Out:
#    Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0    4    0              1       0.70     1.453726          0           1
# 1    4    1              2       0.80     0.905435          0           1
# 2    3    0              1       0.65     1.423544          0           2
# 3    4    1              3       0.69     1.076461          0           1
# 4    5    0              2       0.75     0.980887          0           1
#
#       MaxHR  ExerciseAngina  Oldpeak  ST_Slope  HeartDisease
# 0  1.257224               1      0.0         1             0
# 1  1.140273               1      1.0         2             1
# 2  0.716325               1      0.0         1             0
# 3  0.789420               2      1.5         2             1
# 4  0.891752               1      0.0         1             0

# %%
df['Cholesterol']=round(df['Cholesterol'],2)

# %%
df.head()
# Out:
#    Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0    4    0              1       0.70         1.45          0           1
# 1    4    1              2       0.80         0.91          0           1
# 2    3    0              1       0.65         1.42          0           2
# 3    4    1              3       0.69         1.08          0           1
# 4    5    0              2       0.75         0.98          0           1
#
#       MaxHR  ExerciseAngina  Oldpeak  ST_Slope  HeartDisease
# 0  1.257224               1      0.0         1             0
# 1  1.140273               1      1.0         2             1
# 2  0.716325               1      0.0         1             0
# 3  0.789420               2      1.5         2             1
# 4  0.891752               1      0.0         1             0

# %%
df['MaxHR']=round(df['MaxHR'],2)

# %%
df.head()
# Out:
#    Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0    4    0              1       0.70         1.45          0           1
# 1    4    1              2       0.80         0.91          0           1
# 2    3    0              1       0.65         1.42          0           2
# 3    4    1              3       0.69         1.08          0           1
# 4    5    0              2       0.75         0.98          0           1
#
#    MaxHR  ExerciseAngina  Oldpeak  ST_Slope  HeartDisease
# 0   1.26               1      0.0         1             0
# 1   1.14               1      1.0         2             1
# 2   0.72               1      0.0         1             0
# 3   0.79               2      1.5         2             1
# 4   0.89               1      0.0         1             0

# %%
X=df.drop('HeartDisease',axis=1)

# %%
Y=df['HeartDisease']

# %%
X=df.drop('Sex',axis=1)

# %%
Y
# Out:
# 0      0
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 913    1
# 914    1
# 915    1
# 916    1
# 917    0
# Name: HeartDisease, Length: 918, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,Y,test_size=0.75,random_state=1)

# %%
scores
# Out:
# [0.9521739130434783,
#  0.9391304347826087,
#  0.9608695652173913,
#  0.9608695652173913,
#  0.9608695652173913,
#  0.9608695652173913,
#  0.9565217391304348,
#  0.9478260869565217,
#  0.9434782608695652,
#  0.9478260869565217,
#  0.9478260869565217,
#  0.9521739130434783,
#  0.9521739130434783,
#  0.9521739130434783,
#  0.9521739130434783,
#  0.9521739130434783,
#  0.9521739130434783,
#  0.9521739130434783,
#  0.9565217391304348,
#  0.9521739130434783,
#  0.9565217391304348,
#  0.9521739130434783,
#  0.9565217391304348,
#  0.9521739130434783,
#  0.9478260869565217]

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics

# %%
k_range=range(1,40)
scores = []

for k in k_range:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train, y_train)
    y_pred = knn.predict(X_test)
    scores.append(metrics.accuracy_score(y_test, y_pred))

print(scores)
# Out:
# [0.9375907111756169, 0.9201741654571843, 0.9477503628447025, 0.9404934687953556, 0.9390420899854862, 0.9259796806966618, 0.9375907111756169, 0.9332365747460087, 0.9332365747460087, 0.9259796806966618, 0.9230769230769231, 0.9259796806966618, 0.9259796806966618, 0.9158200290275762, 0.9172714078374455, 0.918722786647315, 0.9143686502177069, 0.9143686502177069, 0.9085631349782293, 0.9114658925979681, 0.9085631349782293, 0.9085631349782293, 0.9085631349782293, 0.9071117561683599, 0.9056603773584906, 0.9042089985486212, 0.8998548621190131, 0.895500725689405, 0.8984034833091437, 0.8911465892597968, 0.8969521044992743, 0.8940493468795355, 0.8940493468795355, 0.8896952104499274, 0.8896952104499274, 0.888243831640058, 0.888243831640058, 0.888243831640058, 0.8853410740203193]

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
fig, ax = plt.subplots(figsize=(10, 10))
plt.plot(k_range, scores)
plt.xlabel('Value of K for KNN')
plt.ylabel('Testing Accuracy')
# Out:
# Text(0, 0.5, 'Testing Accuracy')

# %%
from sklearn.tree import DecisionTreeClassifier 
from sklearn.metrics import confusion_matrix 
from sklearn import metrics
import seaborn as sn
from io import StringIO

# %%
clf=DecisionTreeClassifier()

# %%
clf = clf.fit(X_train,y_train)

# %%
y_pred = clf.predict(X_test)

# %%
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 1.0

# %%
cmat=metrics.confusion_matrix(y_test,y_pred)

# %%
pip install graphviz
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pydotplus
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
fig, ax = plt.subplots(figsize=(7.5, 7.5))
ax.matshow(cmat, cmap=plt.cm.Blues, alpha=0.3)
for i in range(cmat.shape[0]):
    for j in range(cmat.shape[1]):
        ax.text(x=j, y=i,s=cmat[i, j], va='center', ha='center', size='xx-large')
plt.xlabel('Predictions', fontsize=18)
plt.ylabel('Actuals', fontsize=18)
plt.title('Confusion Matrix', fontsize=18)
plt.show()

# %%
df.head(20
       )
# Out:
#     Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0     4    0              1      0.700         1.45          0           1
# 1     4    1              2      0.800         0.91          0           1
# 2     3    0              1      0.650         1.42          0           2
# 3     4    1              3      0.690         1.08          0           1
# 4     5    0              2      0.750         0.98          0           1
# 5     3    0              2      0.600         1.71          0           1
# 6     4    1              1      0.650         1.19          0           1
# 7     5    0              1      0.550         1.05          0           1
# 8     3    0              3      0.700         1.04          0           1
# 9     4    1              1      0.600         1.43          0           1
# 10    3    1              2      0.650         1.06          0           1
# ...
